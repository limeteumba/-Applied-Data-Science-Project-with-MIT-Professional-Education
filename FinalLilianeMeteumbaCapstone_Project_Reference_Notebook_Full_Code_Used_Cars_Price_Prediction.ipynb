# %% [markdown]
# # **Used Cars Price Prediction**

# %% [markdown]
# ## **Executive Summary**

# %% [markdown]
# This projects proposes the Random Forest Tuned model for the prediction of the price of used cars in India. The analysis of used car pricing has revealed several meaningful insights that can guide businesses operating in the used car market. It is suggested that the model will utilize features like Power, Year, kilometers driven, Engine, Mileage, and New price for significant impact on pricing accuracy. The suggested model has proven effective for price prediction. These insights are essential for understanding customer preferences and market dynamics. Accurate price prediction for used cars is crucial in a market where prices vary significantly due to various factors. However, Random Forest models can be computationally expensive, especially if the dataset is large. The training process may take longer and require more computational resources. The model has been tuned meaning that hyperparameters have been optimized to improve its performance. It is recommended that stakeholders consider this factor. Stakeholders should understand the significance of customer preferences and geographical factors in pricing, collaborate to enhance the user experience through user-friendly filters, consider strategies for entering the electric car market or adapting to evolving consumer preferences and continuously monitor power and reliability factors and adapt to changes in the market.

# %% [markdown]
# **Problem Summary**

# %% [markdown]
# The used car market in India is thriving, with approximately 4 million second-hand cars bought and sold in 2018-19, surpassing new car sales. Cars4U, a tech startup, recognizes the immense potential in the pre-owned car market, which has outpaced new car sales in recent years. This shift is indicative of a change in consumer behavior, with many opting for second-hand cars as replacements for their old vehicles. The used car market differs significantly from the new car market, where prices and supply are relatively deterministic and managed by Original Equipment Manufacturers (OEMs). In contrast, the used car market presents several challenges. The pricing of used cars is subject to substantial uncertainty due to various influencing factors, including mileage, brand, model, year, and more. As a result, setting the right price for a used car becomes a complex and critical task, both for sellers and businesses operating in this market. Accurate price prediction for used cars is crucial in a market where prices vary significantly due to various factors. Cars4U aims to address this challenge by developing a pricing scheme that can adapt to the dynamic nature of the used car market. Effectively pricing pre-owned cars will be key to the startup's growth and success in this evolving and highly competitive market.

# %% [markdown]
# **Solution design**

# %% [markdown]
# A number of models or techniques were explored as part of the solution including linear regression, ridge regression, decision tree and random forest(default and tuning versions). Based on the evaluation metrics and considering the trade-off between model complexity and performance, the "Tuned Random Forest Regressor (rf_regressor_tuned)" appears to be the best model. It has a high R-squared value on both the training and test data, indicating good predictive performance. Additionally, it has the lowest RMSE and MAE on the test data, which suggests that it provides accurate predictions. The "Tuned Random Forest Regressor" model is likely to provide accurate predictions of the Price_log feature, which can be valuable for various applications, such as used cars or others pricing predictions or decision support. The tuning process further enhances its performance, making it a valid solution for this complex problem. The most important feature (variable) that has the most significant impact on the model's predictions is Power, followed by Year and features like "kilometers_driven_log," "Engine," "Mileage," and "New_price".

# %% [markdown]
# **Recommendations for Implementation at the end of the project**

# %% [markdown]
# ## **Problem Definition**
#
# ### **The Context:**
#
# The Indian automotive market is experiencing a significant shift with a growing preference for used cars over new ones. Cars4U, a tech startup, recognizes the immense potential in the pre-owned car market, which has outpaced new car sales in recent years. This shift is indicative of a change in consumer behavior, with many opting for second-hand cars as replacements for their old vehicles.
#
# In the 2018-19 fiscal year, new car sales amounted to 3.6 million units, while the sale and purchase of second-hand cars reached around 4 million units. This trend highlights the increased demand for used cars, even as new car sales have faced a slowdown. It's noteworthy that car owners are choosing to replace their old vehicles with pre-owned cars, indicating the changing landscape of the automotive market.
#
# The used car market differs significantly from the new car market, where prices and supply are relatively deterministic and managed by Original Equipment Manufacturers (OEMs). In contrast, the used car market presents several challenges. The pricing of used cars is subject to substantial uncertainty due to various influencing factors, including mileage, brand, model, year, and more. As a result, setting the right price for a used car becomes a complex and critical task, both for sellers and businesses operating in this market.
#
# Cars4U aims to address this challenge by developing a pricing scheme that can adapt to the dynamic nature of the used car market. Effectively pricing pre-owned cars will be key to the startup's growth and success in this evolving and highly competitive market.
#
#
# ### **The objective:**
# The primary objective of this problem is to develop a machine learning model that can accurately predict th eprice of used cars.
#
# To achieve this, the model should comsider various features and factors that influance the price of a used car.
#  Step by step we will:
#  - Eplore and visualize the data
#  - Build a model to predict the prices of used cars
#  - Generate a set of insights and recommendations that will help the business
#
# ### **The key questions:**
#
# - Which factors would affect the price of used cars?
# - Which features impact the most the price of a used car and the final model?
# - What model can predict the best orice of a used car?
# - How do different techniques perform? How do different techniques perform?
# - What are the most meaningful insights relevant to the problem?
#
# ### **The problem formulation**:
#
# Since we have a regression problem at hand, we will try to predict the price of used cars based on several factors such as the brand,model, year of manufacturing, number of seats, mileage, fuel type, location, kilometers driven, transmission, engine, power and the price of a new car.

# %% [markdown]
# ### **Data Dictionary**
#
# **S.No.** : Serial Number
#
# **Name** : Name of the car which includes Brand name and Model name
#
# **Location** : The location in which the car is being sold or is available for purchase (Cities)
#
# **Year** : Manufacturing year of the car
#
# **Kilometers_driven** : The total kilometers driven in the car by the previous owner(s) in KM
#
# **Fuel_Type** : The type of fuel used by the car (Petrol, Diesel, Electric, CNG, LPG)
#
# **Transmission** : The type of transmission used by the car (Automatic / Manual)
#
# **Owner** : Type of ownership
#
# **Mileage** : The standard mileage offered by the car company in kmpl or km/kg
#
# **Engine** : The displacement volume of the engine in CC
#
# **Power** : The maximum power of the engine in bhp
#
# **Seats** : The number of seats in the car
#
# **New_Price** : The price of a new car of the same model in INR 100,000
#
# **Price** : The price of the used car in INR 100,000 (**Target Variable**)

# %% [markdown]
# ### **Loading libraries**

# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Library to split and prepare the data
from sklearn.model_selection import train_test_split
from sklearn import metrics

# Removes the limit for the number of displayed columns
pd.set_option("display.max_columns", None)
# Sets the limit for the number of displayed rows
pd.set_option("display.max_rows", 100)

# Import libraries for building linear regression model
from statsmodels.formula.api import ols
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### **Let us load the data**

# %%
# Load the data
usedcars_df=pd.read_csv("used_cars.csv")
# Copying data to another variable to avoid any changes to original data
data=usedcars_df.copy()

# %%
# Views first 5 and last 5 rows of dataset
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              72000       CNG       Manual      First    26.60   998.0
# 1              41000    Diesel       Manual      First    19.67  1582.0
# 2              46000    Petrol       Manual      First    18.20  1199.0
# 3              87000    Diesel       Manual      First    20.77  1248.0
# 4              40670    Diesel    Automatic     Second    15.20  1968.0
#
#     Power  Seats  New_price  Price
# 0   58.16    5.0        NaN   1.75
# 1  126.20    5.0        NaN  12.50
# 2   88.70    5.0       8.61   4.50
# ...

# %%
data.tail()
# Out:
#       S.No.                                               Name   Location  \
# 7248   7248                  Volkswagen Vento Diesel Trendline  Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI     Mumbai
# 7250   7250                             Nissan Micra Diesel XV    Kolkata
# 7251   7251                             Volkswagen Polo GT TSI       Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...      Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  \
# 7248  2011              89411    Diesel       Manual      First    20.54
# 7249  2015              59000    Petrol    Automatic      First    17.21
# 7250  2012              28000    Diesel       Manual      First    23.08
# 7251  2013              52262    Petrol    Automatic      Third    17.20
# 7252  2014              72443    Diesel    Automatic      First    10.00
#
#       Engine  Power  Seats  New_price  Price
# ...

# %%
# view the different columns variables
data.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_price', 'Price'],
#       dtype='object')

# %% [markdown]
# **Observation:**

# %% [markdown]
# - The variable Price is the target variable and the rest are independent variables based on which we will predict the preice of used cars

# %% [markdown]
# ## Data Overview

# %% [markdown]
# - Observations
# - Sanity checks

# %%
# Understand the shape of the dataset
data.shape
print(f"There are {data.shape[0]} rows and {data.shape[1]} columns.")
# Out:
# There are 7253 rows and 14 columns.

# %%
# ID the unique number of values in the dataset
data.nunique()
# Out:
# S.No.                7253
# Name                 2041
# Location               11
# Year                   23
# Kilometers_Driven    3660
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               438
# Engine                150
# Power                 383
# Seats                   8
# New_price             625
# Price                1373
# dtype: int64

# %%
#Chech the data types of the columns for the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   float64
#  9   Engine             7207 non-null   float64
#  10  Power              7078 non-null   float64
#  11  Seats              7200 non-null   float64
#  12  New_price          1006 non-null   float64
#  13  Price              6019 non-null   float64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 793.4+ KB

# %% [markdown]
# **Observation:**

# %% [markdown]
# - We observe that 5 variables have data type object (Name, location, Fuel_Type, Transmission and  Owner_Type), which means they are string or categorical variables.
# - The remaining variables are all numerical in nature
# - Six columns have missing values (Mileage, Engine, Power, Seats, New_Price and Price)

# %%
#Checking for missing values in the data
data.isnull().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                 175
# Seats                  53
# New_price            6247
# Price                1234
# dtype: int64

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Those greater than zero are Variables with missing values
# - Let's check the percentage of missing values using the code below

# %%
(data.isnull().sum()/data.shape[0])*100
# Out:
# S.No.                 0.000000
# Name                  0.000000
# Location              0.000000
# Year                  0.000000
# Kilometers_Driven     0.000000
# Fuel_Type             0.000000
# Transmission          0.000000
# Owner_Type            0.000000
# Mileage               0.027575
# Engine                0.634220
# Power                 2.412795
# Seats                 0.730732
# New_price            86.129877
# Price                17.013650
# dtype: float64

# %% [markdown]
# **Observation:**

# %% [markdown]
# - The percentage of missing value with less than 5% are Mileage ~0.02%, Engine ~0.6%, Power ~2.4% and Seats ~0.7%
# - The percentage of missing values with more than 5% are New_price ~86% and Price ~17%
# - As the variable S.No is only ID variable, we assume it doesn't have any predictive power to predict the dependent variable. Also, We can observe that S.No. has no null values. Also the number of unique values are equal to the number of observations. So, S.No. looks like an index for the data entry and such a column would not be useful in providing any predictive power for our analysis. Hence, it can be dropped.
# - We will see later how to treat the missing values

# %%
# Remove S.No. column from data. Hint: Use inplace = True
data.drop(columns='S.No.', inplace=True)

# %%
data
# Out:
#                                                    Name    Location  Year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# ...

# %%
#Checking for duplicate values
data.duplicated().sum()
# Out:
# 1

# %% [markdown]
# - There is 1 duplicate in the dataset
# - we will keep the first and drop the second (the duplicate)

# %%
#let see all the diplicated rows in our daatframe including the first one
data[data.duplicated(keep=False)]
# Out:
#                      Name Location  Year  Kilometers_Driven Fuel_Type  \
# 6498  Honda City 1.5 E MT   Mumbai  2010              52000    Petrol
# 6582  Honda City 1.5 E MT   Mumbai  2010              52000    Petrol
#
#      Transmission Owner_Type  Mileage  Engine  Power  Seats  New_price  Price
# 6498       Manual      First     17.0  1497.0  118.0    5.0        NaN    NaN
# 6582       Manual      First     17.0  1497.0  118.0    5.0        NaN    NaN

# %%
# Let's drop the duplicated row but keeping the first
data = data.drop_duplicates(keep='first')

# %%
#Let check to see that it has been dropped
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name, Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats, New_price, Price]
# Index: []

# %%
# The number of rows will decrease by 1
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7252 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7252 non-null   object
#  1   Location           7252 non-null   object
#  2   Year               7252 non-null   int64
#  3   Kilometers_Driven  7252 non-null   int64
#  4   Fuel_Type          7252 non-null   object
#  5   Transmission       7252 non-null   object
#  6   Owner_Type         7252 non-null   object
#  7   Mileage            7250 non-null   float64
#  8   Engine             7206 non-null   float64
#  9   Power              7077 non-null   float64
#  10  Seats              7199 non-null   float64
#  11  New_price          1006 non-null   float64
#  12  Price              6019 non-null   float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 793.2+ KB

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Original number of rows was 7253. Data.info() shows the duplicated row was dropped and the current total number of rows is 7252

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# - EDA is an important part of any project involving data.
# - It is important to investigate and understand the data better before building a model with it.
# - A few questions have been mentioned below which will help you approach the analysis in the right manner and generate insights from the data.
# - A thorough analysis of the data, in addition to the questions mentioned below, should be done.

# %% [markdown]
# **Questions:**
#
# 1. What is the summary statistics of the data? Explore summary statistics for numerical variables and the categorical variables
# 2. Find out number of unique observations in each category of categorical columns? Write your findings/observations/insights
# 3. Check the extreme values in different columns of the given data and write down the observtions? Remove the data where the values are un-realistic

# %%
# Let's check the statistical summary of the data
data.describe(include="all")
# Out:
#                           Name Location         Year  Kilometers_Driven  \
# count                     7252     7252  7252.000000       7.252000e+03
# unique                    2041       11          NaN                NaN
# top     Mahindra XUV500 W8 2WD   Mumbai          NaN                NaN
# freq                        55      948          NaN                NaN
# mean                       NaN      NaN  2013.365830       5.869999e+04
# std                        NaN      NaN     3.254405       8.443351e+04
# min                        NaN      NaN  1996.000000       1.710000e+02
# 25%                        NaN      NaN  2011.000000       3.400000e+04
# 50%                        NaN      NaN  2014.000000       5.342900e+04
# 75%                        NaN      NaN  2016.000000       7.300000e+04
# max                        NaN      NaN  2019.000000       6.500000e+06
#
#        Fuel_Type Transmission Owner_Type      Mileage       Engine  \
# ...

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Cars age goes from 1996 to 2019
# - There is a huge difference between the minimum kilometers driven and the maximum, showing the max being too extreme. Something to question and check why is it too extreme?
# - The kilometers_Driven has extreme values and the corresponding year of the used car, which sparck questionning.
# - Minimum mileage is zero, can mileage of cars be 0? quite not realistic.
# - Price of used cars are lower than those of new cars which make sense as new car always cost more than used cars

# %% [markdown]
# **Let's check the count of each unique category in each of the categorical variables**

# %%
# Making a list of all categorical variables
cat_col = list(data.select_dtypes("object").columns)
# Printing the count of each unique value
for column in cat_col:
    print(data[column].value_counts(normalize=True))
    print("-"*50)
# Out:
# Mahindra XUV500 W8 2WD                  0.007584
# Maruti Swift VDI                        0.006757
# Maruti Swift Dzire VDI                  0.005792
# Honda City 1.5 S MT                     0.005378
# Maruti Swift VDI BSIV                   0.005102
#                                           ...
# Chevrolet Beat LT Option                0.000138
# Skoda Rapid 1.6 MPI AT Elegance Plus    0.000138
# Ford EcoSport 1.5 TDCi Ambiente         0.000138
# Hyundai i10 Magna 1.1 iTech SE          0.000138
# Hyundai Elite i20 Magna Plus            0.000138
# Name: Name, Length: 2041, dtype: float64
# --------------------------------------------------
# Mumbai        0.130723
# Hyderabad     0.120794
# Coimbatore    0.106453
# Kochi         0.106453
# Pune          0.105488
# Delhi         0.091009
# Kolkata       0.090182
# Chennai       0.081495
# Jaipur        0.068809
# Bangalore     0.060673
# Ahmedabad     0.037921
# Name: Location, dtype: float64
# ...

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Mahindra is the most frequent name (brand and model)
# - 13% used cars sold or purchased are from the location Mumbai.
# - 53 % of used cars use Diesel as fuel
# - 71% os used car ar manual
# - 82% of used cars have first ownership

# %% [markdown]
# **Let's explore the two questionable variables above.**
# **Check Kilometers_Driven extreme values**

# %%
# Sort the dataset from high to low order using the variable'Kilometers_Driven'
data.sort_values("Kilometers_Driven", ascending=False).head(20)
# Out:
#                                                  Name   Location  Year  \
# 2328                        BMW X5 xDrive 30d M Sport    Chennai  2017
# 340            Skoda Octavia Ambition Plus 2.0 TDI AT    Kolkata  2013
# 1860                 Volkswagen Vento Diesel Highline    Chennai  2013
# 358                             Hyundai i10 Magna 1.2    Chennai  2009
# 2823  Volkswagen Jetta 2013-2015 2.0L TDI Highline AT    Chennai  2015
# 3092                             Honda City i VTEC SV    Kolkata  2015
# 4491                   Hyundai i20 Magna Optional 1.2  Bangalore  2013
# 6921                      Maruti Swift Dzire Tour LDI     Jaipur  2012
# 3649                                   Tata Indigo LS     Jaipur  2008
# 1528      Toyota Innova 2.5 G (Diesel) 8 Seater BS IV  Hyderabad  2005
# 6919                          ISUZU D-MAX V-Cross 4X4     Jaipur  2017
# 1975                          Skoda Superb 1.8 TSI MT       Pune  2012
# ...

# %% [markdown]
# **Observation:**

# %% [markdown]
# - A car manufactured in 2017 (which is pretty recent) having a 6500000 km driven on is not realistically possible. We can call it a probable data entry error and remove it from the data.

# %%
# Let's drop the 'row' at index 2328 from the data
data.drop(index=2328, inplace=True)

# %%
# Let'check if drop successfully
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7251 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7251 non-null   object
#  1   Location           7251 non-null   object
#  2   Year               7251 non-null   int64
#  3   Kilometers_Driven  7251 non-null   int64
#  4   Fuel_Type          7251 non-null   object
#  5   Transmission       7251 non-null   object
#  6   Owner_Type         7251 non-null   object
#  7   Mileage            7249 non-null   float64
#  8   Engine             7205 non-null   float64
#  9   Power              7076 non-null   float64
#  10  Seats              7198 non-null   float64
#  11  New_price          1006 non-null   float64
#  12  Price              6018 non-null   float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 793.1+ KB

# %% [markdown]
# Row index 2328 was successfully dropped from a total of 7252 to 7251

# %%
# Look at Mileage extreme values
# Sort the dataset from small to high on the variable Mileage
data.sort_values("Mileage", ascending=True).head(20)
# Out:
#                                              Name    Location  Year  \
# 2597                       Hyundai Santro Xing XP        Pune  2007
# 2343                            Hyundai Santro AT   Hyderabad  2006
# 5270                           Honda City 1.5 GXI   Bangalore  2002
# 424          Volkswagen Jetta 2007-2011 1.9 L TDI   Hyderabad  2010
# 6857               Land Rover Freelander 2 TD4 SE      Mumbai  2011
# 443                 Hyundai Santro GLS I - Euro I  Coimbatore  2012
# 5119                       Hyundai Santro Xing XP     Kolkata  2008
# 5022               Land Rover Freelander 2 TD4 SE   Hyderabad  2013
# 5016              Land Rover Freelander 2 TD4 HSE       Delhi  2013
# 2542              Hyundai Santro GLS II - Euro II   Bangalore  2011
# 544   Mercedes-Benz New C-Class Progressive C 200       Kochi  2019
# 1419                       Hyundai Santro Xing XL     Chennai  2007
# 4704          Mercedes-Benz M-Class ML 350 4Matic   Bangalore  2015
# ...

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Mileage of cars cannot be 0 (zero).  One way to handle them is to consider all the zeros as missing values later when we treat missing values.

# %% [markdown]
# ## **Univariate Analysis**

# %% [markdown]
# Univariate analysis is used to explore each variable in a data set, separately. It looks at the range of values, as well as the central tendency of the values. It can be done for both numerical and categorical variables.

# %% [markdown]
# **Questions:**
#
# 1. Do univariate analysis for numerical and categorical variables?
# 2. Check the distribution of the different variables? is the distributions skewed?
# 3. Do we need to do log_transformation, if so for what variables we need to do?
# 4. Perform the log_transformation(if needed) and write down your observations?

# %% [markdown]
# ## **1. Univariate Analysis - Numerical Data**
# Histograms and box plots help to visualize and describe numerical data. We use box plot and histogram to analyse the numerical columns.

# %%
# Function to plot a boxplot and a histogram along the same scale

def histogram_boxplot(data, feature, figsize = (12, 7), kde = False, bins = None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows = 2,      # Number of rows of the subplot grid = 2
        sharex = True,  # x-axis will be shared among all subplots
        gridspec_kw = {"height_ratios": (0.25, 0.75)},
        figsize = figsize,
    )                   # Creating the 2 subplots
    sns.boxplot(
        data = data, x = feature, ax = ax_box2, showmeans = True, color = "violet"
    )                   # Boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data = data, x = feature, kde = kde, ax = ax_hist2, bins = bins, palette = "winter"
    ) if bins else sns.histplot(
        data = data, x = feature, kde = kde, ax = ax_hist2
    )                   # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color = "green", linestyle = "--"
    )                   # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color = "black", linestyle = "-"
    )                   # Add median to the histogram

# %% [markdown]
# **Kilometers-Driven**

# %%
# Plot histogram and box-plot for 'Kilometers_Driven' and to check for any outlier
histogram_boxplot(data, 'Kilometers_Driven')

# %% [markdown]
# **Observation:**

# %% [markdown]
# - The distribution is highly skewed to the right with a mean and median close to 55k.
# - There are outliers
# - Maybe log transformation can help decrease the skewness or linearize the relationship or normalize the variable data or reduce the impact of outliers

# %%
# Log transformation of the feature 'Kilometers_Driven'
sns.distplot(np.log(data["Kilometers_Driven"]), axlabel = "Log(Kilometers_Driven)")
# Out:
# <Axes: xlabel='Log(Kilometers_Driven)', ylabel='Density'>

# %% [markdown]
# **Observation:**

# %% [markdown]
# - The distibution seems to be have been normalized with the log transformation
# - We see that applying log have reduced the skewness
# - Call the new variable Kilometers_driven_log

# %%
# Let's add a transformed kilometers_driven feature in data as Kilometers_driven_log
data["kilometers_driven_log"] = np.log(data["Kilometers_Driven"])

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0
#
#    New_price  Price  kilometers_driven_log
# 0        NaN   1.75              11.184421
# ...

# %% [markdown]
# **Let's analyze the 'Price' variable**

# %%
# Plot histogram and box-plot for 'Price' and to check any outlier
histogram_boxplot(data, 'Price')

# %% [markdown]
# **Observation:**

# %% [markdown]
# - The distribution of Price is also highly skewed, we can also log transformed the column to se if it will help reduce the skewness and normalize the distribution.
# - There are outliers
# - If it helps reduce skewness, add the new price_log to the dataset

# %%
# Log transformation of the feature 'Price'
sns.distplot(np.log(data["Price"]), axlabel = "Log(Price)")
# Out:
# <Axes: xlabel='Log(Price)', ylabel='Density'>

# %% [markdown]
# **Observation:**

# %% [markdown]
# - We can see the distribution has been normalized by log transformation an dthe skewness reduced.
# - We can now add the new variable in the data

# %%
# Let's add a transformed Price feature in data as Price_log
data["Price_log"] = np.log(data["Price"])

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0
#
#    New_price  Price  kilometers_driven_log  Price_log
# 0        NaN   1.75              11.184421   0.559616
# ...

# %% [markdown]
# **Year**

# %%
# Plot histogram and box-plot for 'Year' and to check any outlier
histogram_boxplot(data, 'Year')

# %% [markdown]
# **Observation:**

# %% [markdown]
# - The distribution is skewed to the left
# - Most cars were manufactured between 2014 to 2016
# - There are outliers
# - No need of log transformation

# %% [markdown]
# **Mileage**

# %%
# Plot histogram and box-plot for 'Mileage' and to check any outlier
histogram_boxplot(data, 'Mileage')

# %% [markdown]
# **Observation:**

# %% [markdown]
# - The distribution of the Mileage is uniform
# - There a few outliers
# - Some cars have 0 mileage on, which needs to be treated so they are not considered.

# %% [markdown]
# **Engine**

# %%
# Plot histogram and box-plot for 'Engine' and to check any outlier
histogram_boxplot(data, 'Engine')

# %% [markdown]
# **Observation:**

# %% [markdown]
# - The distribution is slightly skewed to the right
# - There are outliers
# - There are more cars with the displacement volume of the engine around 12000

# %% [markdown]
# **Power**

# %%
# Plot histogram and box-plot for 'Power' and to check any outlier
histogram_boxplot(data, 'Power')

# %% [markdown]
# **Observation:**

# %% [markdown]
# - The distribution is left-skewed
# - There are outliers

# %% [markdown]
# **New_price**

# %%
# Plot histogram and box-plot for 'New_Price' and to check any outlier
histogram_boxplot(data, 'New_price')

# %% [markdown]
# **Observation:**

# %% [markdown]
# - The distribution of New_price is highly skewed to the left
# - There are outliers

# %% [markdown]
# **Seats**

# %%
# Plot histogram and box-plot for 'Seats' and to check any outlier
histogram_boxplot(data, 'Seats')

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Cars with 5 seats are the most frequent

# %% [markdown]
# ## **2. Univariate analysis - Categorical Data**

# %%
# Function to create labeled barplots

def perc_on_bar(data, z):
    '''
    plot
    data: DataFrame or Series
    z: categorical feature
    the function won't work if a column is passed in hue parameter
    '''

    total = len(data[z])  # Length of the column
    plt.figure(figsize=(15, 5))
    ax = sns.countplot(data=data, x=z, palette='Paired', order=data[z].value_counts().index)
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height() / total)  # Percentage of each class of the category
        x = p.get_x() + p.get_width() / 2 - 0.05  # Width of the plot
        y = p.get_y() + p.get_height()  # Height of the plot

        ax.annotate(percentage, (x, y), size=12, ha='center')  # Annotate the percentage with center alignment

    plt.show()

# %% [markdown]
# **Location**

# %%
# Bar Plot for 'Location' variable to see number of cars per city
perc_on_bar(data, 'Location')

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Most (13.1 % of) cars are sold or purchased in Mumbai, followed by 12.1% in Hyderabad
# - Least cars are sold or purchased in Ahmedabad (3.8%)

# %% [markdown]
# **Fuel_Type**

# %%
# Bar Plot for 'Fuel_Type' variable to see number of cars per city
perc_on_bar(data, 'Fuel_Type')

# %% [markdown]
# **Observation:**

# %% [markdown]
# - 53.1% cars use Diesel as fuel, followed by Petrol (45.8%)
# - There is no electric cars

# %% [markdown]
# **Transmission**

# %%
# Bar Plot for 'Transmission' variable to see number of cars per city
perc_on_bar(data, 'Transmission')

# %% [markdown]
# **Observation**

# %% [markdown]
# - Most frequent cars are Manual (71.8%)

# %% [markdown]
# **Owner_Type**

# %%
# Bar Plot for 'Owner_Type' variable to see number of cars per city
perc_on_bar(data, 'Owner_Type')

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Majority of cars is first-own (82.1%)

# %% [markdown]
# **Let's get the Barplot of Year to see which year most cars were manufactured**

# %%
# Bar Plot for 'Year' variable to see when most cars were manufactured
perc_on_bar(data, 'Year')

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Most cars were manufactured in 2014 and 2015 (12.8% each), followed by 2016

# %% [markdown]
# ## **Bivariate Analysis**

# %% [markdown]
# **Questions:**
#
# 1. Plot a scatter plot for the log transformed values(if log_transformation done in previous steps)?
# 2. What can we infer form the correlation heatmap? Is there correlation between the dependent and independent variables?
# 3. Plot a box plot for target variable and categorical variable 'Location' and write your observations?

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0
#
#    New_price  Price  kilometers_driven_log  Price_log
# 0        NaN   1.75              11.184421   0.559616
# ...

# %% [markdown]
# **Scatter Plot**

# %% [markdown]
# A scatter plot allows us to see relationships between two variables.

# %% [markdown]
# We will be using the **log transformed variables**

# %%
# Let's plot Kilometers_driven_log versus Price_log
plt.figure(figsize=[8,6])
sns.scatterplot(x=data.kilometers_driven_log, y=data.Price_log)
plt.show()

# %% [markdown]
# **Observation:**

# %% [markdown]
# - There seem to be no relationship between the Price and the Kilometers_driven

# %%
# Let's plot Year versus Price_log
plt.figure(figsize=[8,6])
sns.scatterplot(x=data.Year, y=data.Price_log)
plt.show()

# %% [markdown]
# **Observation:**

# %% [markdown]
# - There is a positive relationship  between the Price and the Year of manufacturing

# %%
# Let's plot Mileage versus Price_log
plt.figure(figsize=[8,6])
sns.scatterplot(x=data.Mileage, y=data.Price_log)
plt.show()

# %% [markdown]
# **Observation:**

# %% [markdown]
# - There seem to be no relationship  between the Price and the mileage

# %%
# Let's plot Engine versus Price_log
plt.figure(figsize=[8,6])
sns.scatterplot(x=data.Engine, y=data.Price_log)
plt.show()

# %% [markdown]
# **Observation:**

# %% [markdown]
# - There seem to be a positive relatioship between the Price and the Engine

# %%
# Let's plot Power versus Price_log
plt.figure(figsize=[8,6])
sns.scatterplot(x=data.Power, y=data.Price_log)
plt.show()

# %% [markdown]
# **Observation:**

# %% [markdown]
# * There seem to be a positive relationship between the price and the Power

# %%
# Let's plot Seats versus Price_log
plt.figure(figsize=[8,6])
sns.scatterplot(x=data.Price_log, y=data.Seats)
plt.show()

# %% [markdown]
# **Observation:**

# %% [markdown]
# - The is no relationship between the Price and the Seats

# %%
# Let's plot New_Price versus Price_log
plt.figure(figsize=[8,6])
sns.scatterplot(x=data.New_price, y=data.Price_log)
plt.show()

# %% [markdown]
# **Observation:**

# %% [markdown]
# - There seem to be a non-linear positive relationship between the Price of used cars and the price of new cars

# %% [markdown]
# **Heat map**
#
# Heat map shows a 2D correlation matrix between two numerical features.

# %%
# We can include the log transformation values and drop the original skewed data columns
plt.figure(figsize = (12, 7))

sns.heatmap(data.drop(['Price','Kilometers_Driven'],axis = 1).corr(), annot = True, vmin = -1, vmax = 1, cmap="Spectral")

plt.show()

# %% [markdown]
# **Observation:**

# %% [markdown]
# - We observe a positive correlation between the variables the Year, Engine, Power, New_price and the target variable Price_log
# - There is a negative correlation between the Mileage, the Kilometers_drive_log and the target Price_log
# - Power and Engine are highly correlated to each other
# - Power and New_price are highly correlated
# - New_Price and Engine are highly correlated

# %% [markdown]
# **Bivariate boxplots analysis between target variable and categorical variables**

# %%
# Let's check the distribution of our target variable Price with the categorical columns
# The function below takes the categorical column as the input and returns the boxplots for the variable.
def boxplot(z):
    
    plt.figure(figsize = (12, 5)) # Setting size of boxplot
    
    sns.boxplot(x = z, y = data['Price']) # Defining x and y
    
    plt.show()
    
    plt.figure(figsize = (12, 5))
    
    plt.title('Without Outliers')
    
    sns.boxplot(x = z, y = data['Price'], showfliers = False) # Turning off the outliers
    
    plt.show()

# %% [markdown]
# **Location**

# %%
# Price versus Location
boxplot(data['Location'])

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Most expensive used cars are sold or purchased in both Coimbatore and Bangalore

# %% [markdown]
# **Transmission**

# %%
# Price versus Transmission
boxplot(data['Transmission'])

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Automatic cars are more expensive than Manual cars

# %% [markdown]
# **Owner_Type**

# %%
# Price versus Owner_Type
boxplot(data['Owner_Type'])

# %% [markdown]
# **Observation:**

# %% [markdown]
# - First owned cars are more expensive than second, third, fourth and above

# %% [markdown]
# **Fuel_Type**

# %%
# Price versus Fuel_Type
boxplot(data['Fuel_Type'])

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Cars using Diesel as fuel are the most expensive

# %% [markdown]
# ### **Feature Engineering**

# %% [markdown]
# We have too many unique names which combine the model and the brand.

# %% [markdown]
# **Think about it:** The `Name` column in the current format might not be very useful in our analysis.
# Since the name contains both the brand name and the model name of the vehicle, the column would have too many unique values to be useful in prediction. Can we extract that information from that column?

# %% [markdown]
# * **Hint:** With 2041 unique names, car names are not going to be great predictors of the price in our current data. But we can process this column to extract important information for example brand name.

# %% [markdown]
# **We have too many unique names which combine the model and the brand.**
#
# **It will be easier to get information of Brand or Model with less unique numbers from the Names**

# %%
# Let's count unique values for Name
data["Name"].nunique()
# Out:
# 2041

# %%
# Let's extract Brand and Model Names
data[['Brand', 'Model']] = data['Name'].str.split(' ', n=1, expand=True)
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0
#
#    New_price  Price  kilometers_driven_log  Price_log    Brand  \
# ...

# %%
# Unique values for Brand
data["Brand"].nunique()
# Out:
# 33

# %%
# Unique values for Model
data["Model"].nunique()
# Out:
# 2041

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Brand and Model have been extracted and separated
# - Brand column has less unique values and can provide meaningful information

# %% [markdown]
# ### **Missing value treatment**

# %%
# Let's check the missing values of each column 
data.isnull().sum()
# Out:
# Name                        0
# Location                    0
# Year                        0
# Kilometers_Driven           0
# Fuel_Type                   0
# Transmission                0
# Owner_Type                  0
# Mileage                     2
# Engine                     46
# Power                     175
# Seats                      53
# New_price                6245
# Price                    1233
# kilometers_driven_log       0
# Price_log                1233
# Brand                       0
# Model                       0
# dtype: int64

# %% [markdown]
# **Observation:**

# %% [markdown]
# - 6 columns have missed values: Mileage, Engine, Power, Seats, New_price, Price
# - New_price has the most missing values and Mileage the least.

# %% [markdown]
# **Let us check missing values separately and imput those missing values by taking the mean or median**

# %% [markdown]
# **Missing values in Mileage**

# %% [markdown]
# **Mileage equal zero must be treated as missing values**

# %%
# Let's check the number of rows that have mileage equal to zera
len(data[data['Mileage']==0])
# Out:
# 81

# %% [markdown]
# Notes: We have 81 rows with Mileage equal to 0 which is unrealistic. However, since the 81 rows represent a lot of information to dismiss, we will consider the zero Mileage as missing values and imput those zeros with median.

# %%
# Calculate the median of the Mileage column and replace the zeros with mediam
median_mileage=data['Mileage'].median()
data['Mileage'].replace(0, median_mileage, inplace=True)

# %%
# Verify if median mileage imputted
data[data['Mileage']==median_mileage].head(5)
# Out:
#                                          Name    Location  Year  \
# 14             Land Rover Freelander 2 TD4 SE        Pune  2012
# 67   Mercedes-Benz C-Class Progressive C 220d  Coimbatore  2019
# 79                     Hyundai Santro Xing XL   Hyderabad  2005
# 194                        Honda City 1.5 GXI   Ahmedabad  2007
# 229                          Ford Figo Diesel   Bangalore  2015
#
#      Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 14               85000    Diesel    Automatic     Second    18.16  2179.0
# 67               15369    Diesel    Automatic      First    18.16  1950.0
# 79               87591    Petrol       Manual      First    18.16  1086.0
# 194              60006    Petrol       Manual      First    18.16     NaN
# 229              70436    Diesel       Manual      First    18.16  1498.0
#
#      Power  Seats  New_price  Price  kilometers_driven_log  Price_log  \
# ...

# %%
# Verify no more missing 
len(data[data['Mileage']==0])
# Out:
# 0

# %% [markdown]
# **Let us treat the NaN missing value for Mileage**

# %%
# Now check missing values of the Mileage column
data[data['Mileage'].isnull()]
# Out:
#                            Name Location  Year  Kilometers_Driven Fuel_Type  \
# 4446       Mahindra E Verito D4  Chennai  2016              50000  Electric
# 4904  Toyota Prius 2009-2016 Z4   Mumbai  2011              44000  Electric
#
#      Transmission Owner_Type  Mileage  Engine  Power  Seats  New_price  Price  \
# 4446    Automatic      First      NaN    72.0   41.0    5.0      13.58  13.00
# 4904    Automatic      First      NaN  1798.0   73.0    5.0        NaN  12.75
#
#       kilometers_driven_log  Price_log     Brand               Model
# 4446              10.819778   2.564949  Mahindra         E Verito D4
# 4904              10.691945   2.545531    Toyota  Prius 2009-2016 Z4

# %%
# Impute missing Mileage.Let's use the median
# Calculate the median of the Mileage column
median_mileage=data['Mileage'].median()

# Impute median to missing values 
data['Mileage'].fillna(median_mileage, inplace=True)

# %%
# Now check total number of missing values of the Mileage column to verify if they are imputed or not.
data[data['Mileage']==median_mileage].head()
# Out:
#                                          Name    Location  Year  \
# 14             Land Rover Freelander 2 TD4 SE        Pune  2012
# 67   Mercedes-Benz C-Class Progressive C 220d  Coimbatore  2019
# 79                     Hyundai Santro Xing XL   Hyderabad  2005
# 194                        Honda City 1.5 GXI   Ahmedabad  2007
# 229                          Ford Figo Diesel   Bangalore  2015
#
#      Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 14               85000    Diesel    Automatic     Second    18.16  2179.0
# 67               15369    Diesel    Automatic      First    18.16  1950.0
# 79               87591    Petrol       Manual      First    18.16  1086.0
# 194              60006    Petrol       Manual      First    18.16     NaN
# 229              70436    Diesel       Manual      First    18.16  1498.0
#
#      Power  Seats  New_price  Price  kilometers_driven_log  Price_log  \
# ...

# %%
data['Mileage'].isnull().sum()
# Out:
# 0

# %%
len(data[data['Mileage']=='NaN'])
# Out:
# 0

# %% [markdown]
# **Missing values for Engine**

# %%
# Impute missing values in the column Engine
# Calculate the median of the Engine column
median_Engine=data['Engine'].median()

# Impute median to missing values 
data['Engine'].fillna(median_Engine, inplace=True)

# %%
# Now check total number of missing values of the Engine column to verify if they are imputed or not.
data[data['Engine']==median_Engine].head(5)
# Out:
#                                     Name   Location  Year  Kilometers_Driven  \
# 97   Hyundai Verna Transform SX VGT CRDi  Ahmedabad  2010              70002
# 194                   Honda City 1.5 GXI  Ahmedabad  2007              60006
# 200                Mahindra NuvoSport N6    Chennai  2017              29000
# 208                 Maruti Swift 1.3 VXi    Kolkata  2010              42001
# 251                  Hyundai Accent CRDi      Kochi  2006             160538
#
#     Fuel_Type Transmission Owner_Type  Mileage  Engine  Power  Seats  \
# 97     Diesel       Manual      First    16.20  1493.0  110.0    5.0
# 194    Petrol       Manual      First    18.16  1493.0    NaN    NaN
# 200    Diesel       Manual     Second    17.45  1493.0  100.0    7.0
# 208    Petrol       Manual      First    16.10  1493.0    NaN    NaN
# 251    Diesel       Manual      First    13.10  1493.0   82.0    5.0
#
#      New_price  Price  kilometers_driven_log  Price_log     Brand  \
# ...

# %%
data['Engine'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Missing values for Power**

# %%
# Impute missing values in the column Power
# Calculate the median of the Engine column
median_Power=data['Power'].median()

# Impute median to missing values 
data['Power'].fillna(median_Power, inplace=True)

# %%
# Now check total number of missing values of the Power column to verify if they are imputed or not.
data[data['Power']==median_Power].head(5)
# Out:
#                                      Name   Location  Year  Kilometers_Driven  \
# 76               Ford Fiesta 1.4 SXi TDCi     Jaipur  2008             111111
# 79                 Hyundai Santro Xing XL  Hyderabad  2005              87591
# 89                 Hyundai Santro Xing XO  Hyderabad  2007              73745
# 120  Hyundai Santro Xing XL eRLX Euro III     Mumbai  2005             102000
# 143   Hyundai Santro Xing XO eRLX Euro II      Kochi  2008              80759
#
#     Fuel_Type Transmission Owner_Type  Mileage  Engine  Power  Seats  \
# 76     Diesel       Manual      First    17.80  1399.0   94.0    5.0
# 79     Petrol       Manual      First    18.16  1086.0   94.0    5.0
# 89     Petrol       Manual      First    17.00  1086.0   94.0    5.0
# 120    Petrol       Manual     Second    17.00  1086.0   94.0    5.0
# 143    Petrol       Manual      Third    17.00  1086.0   94.0    5.0
#
#      New_price  Price  kilometers_driven_log  Price_log    Brand  \
# ...

# %%
data['Power'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Missing values for Seats**

# %%
# Checking missing values in the column 'Seats'
data[data['Seats'].isnull()].head(5)
# Out:
#                              Name   Location  Year  Kilometers_Driven  \
# 194            Honda City 1.5 GXI  Ahmedabad  2007              60006
# 208          Maruti Swift 1.3 VXi    Kolkata  2010              42001
# 229              Ford Figo Diesel  Bangalore  2015              70436
# 733          Maruti Swift 1.3 VXi    Chennai  2006              97800
# 749  Land Rover Range Rover 3.0 D     Mumbai  2008              55001
#
#     Fuel_Type Transmission Owner_Type  Mileage  Engine  Power  Seats  \
# 194    Petrol       Manual      First    18.16  1493.0   94.0    NaN
# 208    Petrol       Manual      First    16.10  1493.0   94.0    NaN
# 229    Diesel       Manual      First    18.16  1498.0   99.0    NaN
# 733    Petrol       Manual      Third    16.10  1493.0   94.0    NaN
# 749    Diesel    Automatic     Second    18.16  1493.0   94.0    NaN
#
#      New_price  Price  kilometers_driven_log  Price_log   Brand  \
# ...

# %%
# Impute missing values in Seats,you can use fillna method in pandas
# Calculate the median of the Seats column
median_Seats=data['Seats'].median()

# Impute median to missing values 
data['Seats'].fillna(median_Seats, inplace=True)

# %%
# Now check total number of missing values of the seats column to verify if they are imputed or not.
data[data['Seats']==median_Seats].head(5)
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 5   Hyundai EON LPG Era Plus Option   Hyderabad  2012              75000
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0
# 5       LPG       Manual      First    21.10   814.0   55.20    5.0
#
#    New_price  Price  kilometers_driven_log  Price_log    Brand  \
# ...

# %%
data['Seats'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Missing values for New_price**

# %%
# Impute missing values in the column New_price
# Calculate the median of the New_price column
median_New_price=data['New_price'].median()

# Impute median to missing values 
data['New_price'].fillna(median_New_price, inplace=True)

# %%
# Now check total number of missing values of the New_price column to verify if they are imputed or not.
data[data['New_price']==median_New_price].head(5)
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 5   Hyundai EON LPG Era Plus Option   Hyderabad  2012              75000
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0
# 5       LPG       Manual      First    21.10   814.0   55.20    5.0
#
#    New_price  Price  kilometers_driven_log  Price_log    Brand  \
# ...

# %%
data['New_price'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Missing values for Price**

# %% [markdown]
# **If we drop the Price missing value we will loose a lot of information from other columns. We will then imput the median method to tyhe Price**

# %%
# Let's check the Price missing values
data[data['Price_log'].isna()].head()
# Out:
#                                            Name    Location  Year  \
# 6019                    Maruti Alto K10 LXI CNG       Delhi  2014
# 6020              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 6021  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 6022                       Toyota Etios Liva GD   Hyderabad  2012
# 6023                          Hyundai i20 Magna      Mumbai  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 6019              40929       CNG       Manual      First    32.26   998.0
# 6020              54493    Petrol       Manual     Second    24.70   796.0
# 6021              34000    Diesel       Manual      First    13.68  2393.0
# 6022             139000    Diesel       Manual      First    23.59  1364.0
# 6023              29000    Petrol       Manual      First    18.50  1197.0
#
#        Power  Seats  New_price  Price  kilometers_driven_log  Price_log  \
# ...

# %%
# Let's imput the Price missing values with median
# Calculate the median of the Price column
median_Price_log=data['Price_log'].median()

# Impute median to missing values 
data['Price_log'].fillna(median_Price_log, inplace=True)

# %%
# Now check total number of missing values of the Price column to verify if they are imputed or not.
data[data['Price_log']==median_Price_log].head(5)
# Out:
#                                                Name    Location  Year  \
# 702                          Hyundai Grand i10 Asta  Coimbatore  2017
# 901   Volkswagen Jetta 2012-2014 2.0L TDI Trendline       Kochi  2012
# 1720                       Hyundai Grand i10 Sportz  Coimbatore  2015
# 2296                    Hyundai i20 Sportz 1.4 CRDi       Delhi  2014
# 3704                       Hyundai Verna SX CRDi AT       Delhi  2013
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 702               74515    Petrol       Manual      First    18.90  1197.0
# 901               58775    Diesel       Manual      First    19.33  1968.0
# 1720              36840    Petrol       Manual      First    18.90  1197.0
# 2296              55000    Diesel       Manual      First    22.54  1396.0
# 3704              51000    Diesel    Automatic      First    19.08  1582.0
#
#        Power  Seats  New_price  Price  kilometers_driven_log  Price_log  \
# ...

# %%
data['Price'].isnull().sum()
# Out:
# 1233

# %%
# Check the null values in the data
data.isnull().sum()
# Out:
# Name                        0
# Location                    0
# Year                        0
# Kilometers_Driven           0
# Fuel_Type                   0
# Transmission                0
# Owner_Type                  0
# Mileage                     0
# Engine                      0
# Power                       0
# Seats                       0
# New_price                   0
# Price                    1233
# kilometers_driven_log       0
# Price_log                   0
# Brand                       0
# Model                       0
# dtype: int64

# %% [markdown]
# **Observations after imputting:**

# %% [markdown]
# - All missing values has been treated by imputting the median method.
# - Mileages equal to zero or with NaN were treated by imputting median.
# - There are no missing values anymore.

# %% [markdown]
# ## **Important Insights from EDA and Data Preprocessing**
#
# What are the the most important observations and insights from the data based on the EDA and Data Preprocessing performed?

# %% [markdown]
# - The variable Price is the target variable and the rest are independent variables based on which we will predict the price of used cars
# - Columns and rows have been dropped as bad predictors (S.No.) or as extrems values (row 2328 of Kilometers_Driven) or as duplicate()
# - Most (13.1 % of) cars are sold or purchased in Mumbai, followed by 12.1% in Hyderabad
# - Least cars are sold or purchased in Ahmedabad (3.8%)
# - 53.1% cars use Diesel as fuel, followed by Petrol (45.8%)
# - There is no electric cars
# - Cars with 5 seats are the most frequent
# - Most frequent cars are Manual (71.8%)
# - Majority of cars is first-own (82.1%)
# - Most cars were manufactured in 2014 and 2015 (12.8% each), followed by 2016
# - We observe a positive correlation between the variables the Year, Engine, Power, New_price and the target variable Price_log
# - There is a negative correlation between the Mileage, the Kilometers_drive_log and the target Price_log
# - Most expensive used cars are sold or purchased in both Coimbatore and Bangalore
# - Automatic cars are more expensive than Manual cars
# - First owned cars are more expensive than second, third, fourth and above
# - Cars using Diesel as fuel are the most expensive
# - Brand and Model have been extracted and separated

# %% [markdown]
# ## **Building Various Models**
#
#
# 1. What we want to predict is the "Price". We will use the normalized version 'price_log' for modeling.
# 2. Before we proceed to the model, we'll have to encode categorical features. We will drop categorical features like Name.
# 3. We'll split the data into train and test, to be able to evaluate the model that we build on the train data.
# 4. Build Regression models using train data.
# 5. Evaluate the model performance.

# %% [markdown]
# ### **Split the Data**

# %% [markdown]
# <li>Step1: Separating the indepdent variables (X) and the dependent variable (y).
# <li>Step2: Encode the categorical variables in X using pd.dummies.
# <li>Step3: Split the data into train and test using train_test_split.

# %%
# Let's create a function to calculate the performance metrics for our regression model so that we don't need to use the same code repeatedly.
from sklearn.metrics import r2_score
def get_model_score(model, flag = True):
    '''
    model : regressor to predict values of X

    '''
    # Defining an empty list to store train and test results
    score_list = [] 
    
    pred_train = model.predict(X_train)
    
    
    
    pred_test = model.predict(X_test)
    
    
    
    train_r2 = "{:.3f}".format(metrics.r2_score(y_train, pred_train))
    
    test_r2 = "{:.3f}".format(metrics.r2_score(y_test, pred_test))
    
    train_rmse = "{:.3f}".format(metrics.mean_squared_error(y_train, pred_train, squared = False))
    
    test_rmse = "{:.3f}".format(metrics.mean_squared_error(y_test, pred_test, squared = False))
    
    train_mae = "{:.3f}".format(metrics.mean_absolute_error(y_train, pred_train))
    
    test_mae = "{:.3f}".format(metrics.mean_absolute_error(y_test, pred_test))
    
    # Adding all scores in the list
    #score_list.extend((train_r2, test_r2, train_rmse, test_rmse, train_mae, test_mae))
    score_dict={'R-Squared': [train_r2, test_r2], 'RMSE': [train_rmse, test_rmse],  'MAE': [train_mae, test_mae]}
    score_table = pd.DataFrame(score_dict, index=['train', 'test'])
    
    # Create a table displaying all the performance metrics
    
    # If the flag is set to True then only the following print statements will be dispayed, the default value is True
    if flag == True: 
        
        print("R-squared on training set: {:.3f}".format(metrics.r2_score(y_train, pred_train)))
        
        print("R-square on test set: {:.3f}".format(metrics.r2_score(y_test, pred_test)))
        
        print("RMSE on training set: {:.3f}".format(np.sqrt(metrics.mean_squared_error(y_train, pred_train))))
        
        print("RMSE on test set : {:.3f}".format(np.sqrt(metrics.mean_squared_error(y_test, pred_test))))
        
        print("MAE on training set: {:.3f}".format(np.sqrt(metrics.mean_absolute_error(y_train, pred_train))))
        
        print("MAE on test set: {:.3f}".format(np.sqrt(metrics.mean_absolute_error(y_test, pred_test))))
    
    # Returning the list with train and test scores
    return score_table

# %% [markdown]
# **We will drop 'Name','Price','price_log','Kilometers_Driven' from X before splitting because Name is not a valuable predictor, Price/Price_log is the target and will be on Y and we will used Kilometers_driven_log which the normalized version instead.**

# %%
# Step1 : Use pd.get_dummies(drop_first = True is used to avoid redundant variables )
# Let's dummies all categorical variables and drop Name and Model(because of unique numbers too large)
data_processing = pd.get_dummies(data.drop(columns=['Name','Model']), drop_first = True)

# %%
# Step2: Separating features and the target column
X = data_processing.drop(columns=['Price','Price_log','Kilometers_Driven'])

y = data_processing["Price_log"]

# %%
# Step3: Splitting the data into train and test sets in 70:30 ratio
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)
print("Shape of Training set : ", X_train.shape, "Shape of test set : ", X_test.shape)
# Out:
# Shape of Training set :  (5075, 57) Shape of test set :  (2176, 57)

# %% [markdown]
# For Regression Problems, some of the algorithms used are :<br>
#
# **1) Linear Regression** <br>
# **2) Ridge / Lasso Regression** <br>
# **3) Decision Trees** <br>
# **4) Random Forest** <br>

# %% [markdown]
# ### **Linear Regression**

# %% [markdown]
# **Building a model using sklearn**.

# %%
# Import Linear Regression from sklearn
from sklearn.linear_model import LinearRegression
# Create a linear regression model
lr = LinearRegression()

# %%
# Fit linear regression model
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr_perf=get_model_score(lr, flag = True)
lr_perf
# Out:
# R-squared on training set: 0.770
# R-square on test set: 0.792
# RMSE on training set: 0.382
# RMSE on test set : 0.363
# MAE on training set: 0.517
# MAE on test set: 0.511
#       R-Squared   RMSE    MAE
# train     0.770  0.382  0.267
# test      0.792  0.363  0.261

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Training R² (0.770) explains approximately 77% of the variance in Price_log in the training dataset.
# - Test R² (0.792) explains approximately 79.2% of the variance in the target variable in the test dataset. It's slightly higher than the training R², which is a positive sign. However, R² alone may not tell the whole story about the model's performance.
# - A lower RMSE indicates that, on average, the model's predictions are close to the actual values. In this case, the training RMSE is 0.382, which means that, on average, the model's predictions deviate by approximately 0.382 units from the actual prices in the training data.
# - Test RMSE (0.363) is slightly lower (better) than the training RMSE (0.363), which is a positive sign. Lower RMSE values are desirable.
# - Training MAE (0.267). In the training dataset, the model's predictions deviate, on average, by approximately 0.267 units from the actual prices.
# - Test MAE (0.261) is slightly lower (better) than the training MAE (0.261).
#
#   **the model appears to have reasonably good performance**

# %% [markdown]
# **Building a model using statsmodels.**

# %%
# Import Statsmodels 
import statsmodels.api as sm

# Statsmodel api does not add a constant by default. We need to add it explicitly
x_train = sm.add_constant(X_train)

# Add constant to test data
x_test = sm.add_constant(X_test)

def lr (train):
    
    # Create the model
    lr = sm.OLS(y_train, train)
    
    return lr.fit()


# Fit linear model on new dataset
lr_model = lr(x_train)

print(lr_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Price_log   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                     306.2
# Date:                Thu, 19 Oct 2023   Prob (F-statistic):               0.00
# Time:                        20:20:09   Log-Likelihood:                -2311.8
# No. Observations:                5075   AIC:                             4736.
# Df Residuals:                    5019   BIC:                             5101.
# Df Model:                          55
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      -199.3768      4.990    -39.957      0.000    -209.159    -189.595
# ...

# %%
# Get Coeff values, p-values and store them in the dataframe
coeff_p_values_df = pd.DataFrame(lr_model.params, columns = ['coef'])

coeff_p_values_df['pval'] = lr_model.pvalues

coeff_p_values_df
# Out:
#                                    coef           pval
# const                     -1.993768e+02  2.246853e-303
# Year                       9.974479e-02   0.000000e+00
# Mileage                   -1.128202e-02   9.857088e-06
# Engine                     2.075170e-04   7.051193e-13
# Power                      3.777765e-03   2.593683e-34
# Seats                      3.679809e-02   4.713481e-04
# New_price                 -8.826931e-04   9.952483e-02
# kilometers_driven_log     -5.767201e-02   1.331219e-08
# Location_Bangalore         1.019677e-01   4.826931e-03
# Location_Chennai           2.460174e-02   4.657416e-01
# Location_Coimbatore        7.644839e-02   1.989451e-02
# Location_Delhi            -6.725581e-02   4.218072e-02
# Location_Hyderabad         8.803159e-02   5.728844e-03
# Location_Jaipur           -5.150413e-02   1.401878e-01
# Location_Kochi            -4.418872e-02   1.773713e-01
# Location_Kolkata          -1.900793e-01   1.308725e-08
# ...

# %% [markdown]
# **Some definitions**
# - Coefficients (coef): These values represent the impact or weight of each feature on the target variable in your regression model. For example, a positive coefficient indicates that an increase in that feature's value leads to an increase in the target variable, while a negative coefficient suggests the opposite. The magnitude of the coefficient represents the strength of this relationship.
#
# - P-values (pval): P-values are used to test the significance of each feature's coefficient. A low p-value (typically below a significance level like 0.05) indicates that the feature is statistically significant in predicting the target variable. In other words, low p-values suggest that the coefficient is unlikely to be zero.

# %%
# Filter by significant p-value (pval <= 0.05) and sort from greater to smaller

coeff_p_values_df = coeff_p_values_df.sort_values(by = "pval", ascending = False)

pval_filter = coeff_p_values_df['pval']<= 0.05

coeff_p_values_df[pval_filter]
# Out:
#                              coef           pval
# Location_Delhi          -0.067256   4.218072e-02
# Location_Coimbatore      0.076448   1.989451e-02
# Owner_Type_Third        -0.095473   1.904113e-02
# Owner_Type_Second       -0.039024   1.575772e-02
# Brand_Mini               0.996371   1.180270e-02
# Brand_Land               1.059464   6.773710e-03
# Location_Hyderabad       0.088032   5.728844e-03
# Fuel_Type_Electric       1.082143   5.537472e-03
# Location_Bangalore       0.101968   4.826931e-03
# Brand_Hindustan          1.810577   9.095252e-04
# Seats                    0.036798   4.713481e-04
# Fuel_Type_Diesel         0.229577   2.000143e-04
# Mileage                 -0.011282   9.857088e-06
# Transmission_Manual     -0.092004   4.365248e-07
# kilometers_driven_log   -0.057672   1.331219e-08
# Location_Kolkata        -0.190079   1.308725e-08
# Engine                   0.000208   7.051193e-13
# Power                    0.003778   2.593683e-34
# ...

# %% [markdown]
# **Observation:**

# %% [markdown]
# - The feature "Location_Delhi" has a negative coefficient of -0.067256 and a p-value of 0.042181. This suggests that being in the "Delhi" location has a negative impact on the Price, and the relationship is statistically significant.
#
# - The feature "Location_Coimbatore" has a positive coefficient of 0.076448 and a p-value of 0.019895. Being in the "Coimbatore" location has a positive impact on the Price, and this relationship is statistically significant.
#
# - The feature "Owner_Type_Third" has a negative coefficient of -0.095473 and a p-value of 0.019041. Having the "Third" owner type negatively affects the Price, and this relationship is statistically significant.
#
# - The feature "Power" has a positive coefficient of 0.003778 and an extremely low p-value (2.593683e-34), indicating strong statistical significance. An increase in "Power" has a positive impact on the Price.
#
# - The feature "const" represents the intercept term of the regression model, and its coefficient is -199.376781. This value is usually associated with the base or reference level.

# %%
# We are looking for overall significant varaible

pval_filter = coeff_p_values_df['pval']<= 0.05
imp_vars = coeff_p_values_df[pval_filter].index.tolist()

# We are going to get overall variables (un-one-hot encoded varables) from categorical varaibles
sig_var = []
for col in imp_vars:
    if '' in col:
        first_part = col.split('_')[0]
        for c in data_processing.columns:
            if first_part in c and c not in sig_var :
                sig_var.append(c)

                
start = '\033[1m'
end = '\033[95m'
print(start+ 'Most overall significant categorical varaibles of LINEAR REGRESSION  are ' +end,':\n', sig_var)
# Out:
# Most overall significant categorical varaibles of LINEAR REGRESSION  are  :
# ...

# %% [markdown]
# ### **Build Ridge / Lasso Regression similar to Linear Regression:**<br>

# %%
# Import Ridge/ Lasso Regression from sklearn
from sklearn.linear_model import Ridge, Lasso

# %%
# Create a Ridge regression model
ridge_model = Ridge(alpha=1.0) # alpha-regularization strenght

# %%
# Fit Ridge regression model
ridge_model.fit(X_train, y_train)
# Out:
# Ridge()

# %%
# Get score of the model
ridge_model_perf= get_model_score(ridge_model,flag = True )

ridge_model_perf
# Out:
# R-squared on training set: 0.770
# R-square on test set: 0.793
# RMSE on training set: 0.382
# RMSE on test set : 0.363
# MAE on training set: 0.518
# MAE on test set: 0.511
#       R-Squared   RMSE    MAE
# train     0.770  0.382  0.268
# test      0.793  0.363  0.261

# %% [markdown]
# **Observation:**

# %% [markdown]
# - The train and the test scores are very close to each other. So, we can say the model is not overfitting.
# - Training R² (0.770) indicates that the model explains approximately 77% of the variance in Price_log in the training dataset.
# - Test R² (0.793) suggests that the model explains approximately 79.3% of the variance in the target variable in the test dataset. It's slightly higher than the training R², which is a positive sign. However, R² alone may not tell the whole story about the model's performance.
# - The training RMSE is 0.382, which means that, on average, the model's predictions deviate by approximately 0.382 units from the actual prices in the training data.
# - Test RMSE (0.363) is slightly lower (better) than the training RMSE (0.363), which is a positive sign. Lower RMSE values are desirable.
# - RMSE and MAE are relatively low suggesting that the model"s prewdictions are close to the actual values.
# - Test RMSE (0.363) is slightly lower (better) than the training RMSE (0.363), which is a positive sign. Lower RMSE values are desirable.
# - Test MAE (0.261) is slightly lower (better) than the training MAE (0.261).
#
# **The model appears to have reasonably good performance**

# %% [markdown]
# ### **Decision Tree**

# %%
# Import Decision tree for Regression from sklearn
from sklearn.tree import DecisionTreeRegressor

# %%
# Create a Decision Tree Regressor
dt_regressor = DecisionTreeRegressor(random_state = 1)

# %%
# Fitting the model
dt_regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
# Model Performance on the test data, i.e., prediction
dt_regressor_perf= get_model_score(dt_regressor,flag = True)

dt_regressor_perf
# Out:
# R-squared on training set: 1.000
# R-square on test set: 0.561
# RMSE on training set: 0.008
# RMSE on test set : 0.528
# MAE on training set: 0.020
# MAE on test set: 0.577
#       R-Squared   RMSE    MAE
# train     1.000  0.008  0.000
# test      0.561  0.528  0.333

# %% [markdown]
# **Observation:**

# %% [markdown]
# - r2 training of 1 indicates a perfect fit to the training data, explaining 100% of the variance in the Price_log. However, while this value may seem desirable, a training r2 of 1.000 suggests that the model has essentially memorized the training dada and fits perfectly. This is a strong eveidence of overfitting.
# - Test r2 is significantly lower that the training r2, suggesting that the model's performance on the test data is not as good. A lower test r2 compared to the training r2 is another indication of overfitting.
# - Training RMSE (0.008): The training RMSE is extremely low, indicating that the model's predictions are very close to the actual values in the training dataset. This is consistent with a perfect fit but raises concerns about overfitting.
# - Test RMSE (0.528): The test RMSE is significantly higher than the training RMSE. A higher test RMSE relative to the training RMSE suggests overfitting and that the model's performance on the test data is not as good.
# - Training MAE (0.000): The training MAE is also very low, indicating that the model's predictions are extremely close to the actual values in the training dataset. Like the other metrics, it is indicative of overfitting.
# - Test MAE (0.333): The test MAE is significantly higher than the training MAE, again suggesting that the model may not generalize well to new data.
#
# **the model's perfect fit to the training data, as evidenced by a training R² of 1.000 and extremely low RMSE and MAE, strongly suggests overfitting. The lower performance on the test data, as indicated by the lower R², higher RMSE, and MAE, reinforces the overfitting concern.**

# %% [markdown]
# **The values in the "Importance" column represent the importance scores for each feature. Higher values indicate that the feature has a more significant impact on the model's predictions.**

# %%
# Plotting the feature importance
feature_importances = dt_regressor.feature_importances_
importances = dt_regressor.feature_importances_
columns = X.columns;
importance_df_astro = pd.DataFrame(importances, index=columns, columns=['Importance']).sort_values(by='Importance', ascending=False);
plt.figure(figsize=(13,13));
sns.barplot(x=importance_df_astro.Importance,y= importance_df_astro.index)
plt.show()

print(importance_df_astro)
# Out:
#                              Importance
# Power                      5.482780e-01
# Year                       2.045775e-01
# kilometers_driven_log      6.342559e-02
# Engine                     3.721377e-02
# Mileage                    2.974054e-02
# New_price                  1.243076e-02
# Brand_Land                 7.967517e-03
# Location_Kolkata           6.858640e-03
# Location_Coimbatore        6.240412e-03
# Owner_Type_Second          6.016919e-03
# Location_Mumbai            5.833953e-03
# Location_Hyderabad         5.085214e-03
# Location_Kochi             4.711863e-03
# Location_Pune              4.101451e-03
# Brand_BMW                  3.870894e-03
# Transmission_Manual        3.694027e-03
# Location_Jaipur            3.609466e-03
# Location_Delhi             3.577655e-03
# Brand_Mini                 3.466031e-03
# Brand_Tata                 3.448638e-03
# Brand_Mercedes-Benz        2.853536e-03
# Fuel_Type_Diesel           2.790754e-03
# ...

# %% [markdown]
# **Observation:**

# %% [markdown]
# - "Power" is the most important feature, with an importance score of approximately 0.548. This suggests that the "Power" feature has the most substantial influence on the model's predictions.
#
# - "Year" is the second most important feature, with an importance score of approximately 0.205. It indicates that the age of the vehicle (year of manufacture) is also a significant factor in predicting the target variable.
#
# - "kilometers_driven_log" is the third most important feature, with an importance score of approximately 0.063. It appears to be a transformed version of the "kilometers_driven" feature, indicating that the logarithm of kilometers driven is important in the model.
#
# - Other features, such as "Engine," "Mileage," "New_price," and various categorical features related to brand, location, owner type, and fuel type, also contribute to the model's predictions to varying degrees.
#
# - Some features, such as "Brand_Bentley," "Brand_Lamborghini," "Brand_Force," and others, have zero importance in the model, which means they do not influence the predictions at all.

# %% [markdown]
# ### **Random Forest**

# %%
# Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
#Create a Random forest Regressor
rf_regressor = RandomForestRegressor(n_estimators = 100, random_state = 1)

# %%
# Fitting the model
rf_regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=1)

# %%
# Model Performance on the test data
rf_regressor_perf= get_model_score(rf_regressor,flag = True )

rf_regressor_perf
# Out:
# R-squared on training set: 0.964
# R-square on test set: 0.762
# RMSE on training set: 0.150
# RMSE on test set : 0.388
# MAE on training set: 0.311
# MAE on test set: 0.510
#       R-Squared   RMSE    MAE
# train     0.964  0.150  0.097
# test      0.762  0.388  0.260

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Training R² (0.964) indicates that the model explains approximately 96.4% of the variance of Price_log in the training dataset.
# - Test R² (0.762) indicates that the model explains approximately 76.2% of the variance in the Price_log in the test dataset. The test R² is slightly lower than the training R², which is expected, but it's still relatively high, indicating a good fit
# - A low RMSE (0.150) suggests that, on average, the model's predictions are very close to the actual values in the training data.
# - Test RMSE (0.388). While it is slightly higher than the training RMSE, it's still relatively low, indicating that the model's predictions are reasonably close to the actual values in the test data.
# - Training MAE (0.097): MAE is another measure of the average prediction error.
# - Test MAE is slightly higher than the training MAE (0.260), but still relatively low.
#
# - The R² values are around 0.76-0.96, indicating that the model explains a significant portion of the variance in the target variable in both the training and test datasets.
# - The RMSE and MAE values are relatively low, suggesting that the model's predictions are close to the actual values.
#
#  **The model appears to have good performance**

# %% [markdown]
# **Feature importance**

# %%
# Plotting the feature importance
feature_importances = dt_regressor.feature_importances_
importances = rf_regressor.feature_importances_
columns = X.columns;
importance_df_astro = pd.DataFrame(importances, index=columns, columns=['Importance']).sort_values(by='Importance', ascending=False);
plt.figure(figsize=(13,13));
sns.barplot(x=importance_df_astro.Importance,y= importance_df_astro.index)
plt.show()

print(importance_df_astro)
# Out:
#                            Importance
# Power                        0.543162
# Year                         0.204800
# kilometers_driven_log        0.060449
# Engine                       0.039882
# Mileage                      0.032374
# New_price                    0.013566
# Brand_Land                   0.007766
# Location_Kolkata             0.006427
# Seats                        0.005305
# Location_Hyderabad           0.005146
# Location_Coimbatore          0.005118
# Owner_Type_Second            0.005037
# Brand_Tata                   0.004421
# Location_Kochi               0.004058
# Location_Mumbai              0.004033
# Location_Pune                0.003866
# Brand_Mercedes-Benz          0.003769
# Location_Jaipur              0.003664
# Location_Delhi               0.003620
# Brand_BMW                    0.003435
# Transmission_Manual          0.003413
# Brand_Honda                  0.003400
# Location_Chennai             0.003223
# Location_Bangalore           0.002849
# ...

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Power (0.543162): This feature has the highest importance score.
#
# - Year (0.204800): has the second-highest importance score.
#
# - kilometers_driven_log (0.060449): The logarithm of kilometers driven is also significant." It indicates that the transformed feature has an impact on the model's predictions.
#
# - Engine (0.039882) is another relevant factor in the model.
#
# - Mileage (0.032374) also contributes to the model's predictions.
#
# - New_price (0.013566) plays a role in predicting the target variable.
#
# - Brand-related features: It appears that the brand of the vehicle is also a significant factor.
#
# - Location-related features suggest that the location of the sale or purchase may influence the target variable.
#
# - Owner_Type have associated importance scores.
#
# - Fuel_Type also contribute to the model's predictions.
#
# - Seats (0.005305) has a relatively lower importance score but still plays a role in predicting the target variable.
#
# - Transmission is a factor in the model.
#
# - Features with importance scores close to zero (e.g., "Brand_Lamborghini," "Brand_OpelCorsa," "Brand_Force," etc.) have little to no influence on the model's predictions.

# %% [markdown]
# ### **Hyperparameter Tuning: Decision Tree**

# %%
# Choose the type of estimator 
from sklearn.tree import DecisionTreeRegressor
dt_regressor_tuned = DecisionTreeRegressor(random_state = 1)
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, mean_squared_error

# Check documentation for all the parametrs that the model takes and play with those
print(dt_regressor.get_params())

parameters = {
    'max_depth': [None, 5, 10, 15],  # Maximum depth of the tree
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4]  # Minimum number of samples required to be at a leaf node
    # Add more parameters and values as needed
}
# Type of scoring used to compare parameter combinations
from sklearn.metrics import make_scorer
scorer = make_scorer(mean_squared_error, greater_is_better=False)

# Run the grid search
grid_obj = GridSearchCV(estimator=dt_regressor_tuned, param_grid=parameters, scoring=scorer)
grid_obj = grid_obj.fit(X, y)  # Replace X and y with your feature and target data


# Set the model to the best combination of parameters
dt_regressor_tuned = grid_obj.best_estimator_

# Fit the best algorithm to the data
dt_regressor_tuned.fit(X, y) # Replace X and y with your feature and target data
# Out:
# {'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': 1, 'splitter': 'best'}
# DecisionTreeRegressor(max_depth=5, min_samples_leaf=4, random_state=1)

# %%
# Get score of the dt_regressor_tuned
dt_regressor_tuned_perf=get_model_score(dt_regressor_tuned, flag=True)

dt_regressor_tuned_perf
# Out:
# R-squared on training set: 0.715
# R-square on test set: 0.743
# RMSE on training set: 0.425
# RMSE on test set : 0.404
# MAE on training set: 0.554
# MAE on test set: 0.545
#       R-Squared   RMSE    MAE
# train     0.715  0.425  0.307
# test      0.743  0.404  0.297

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Compared to dt_regressor model above  which is overfit, dt_regressor_tuned has reasonably good performance

# %% [markdown]
# **Feature Importance**

# %%
# Plotting the feature importance
feature_importances = dt_regressor_tuned.feature_importances_
columns = X.columns;
importance_df_astro = pd.DataFrame(importances, index=columns, columns=['Importance']).sort_values(by='Importance', ascending=False);
plt.figure(figsize=(13,13));
sns.barplot(x=importance_df_astro.Importance,y= importance_df_astro.index)
plt.show()

print(importance_df_astro)
# Out:
#                            Importance
# Power                        0.543162
# Year                         0.204800
# kilometers_driven_log        0.060449
# Engine                       0.039882
# Mileage                      0.032374
# New_price                    0.013566
# Brand_Land                   0.007766
# Location_Kolkata             0.006427
# Seats                        0.005305
# Location_Hyderabad           0.005146
# Location_Coimbatore          0.005118
# Owner_Type_Second            0.005037
# Brand_Tata                   0.004421
# Location_Kochi               0.004058
# Location_Mumbai              0.004033
# Location_Pune                0.003866
# Brand_Mercedes-Benz          0.003769
# Location_Jaipur              0.003664
# Location_Delhi               0.003620
# Brand_BMW                    0.003435
# Transmission_Manual          0.003413
# Brand_Honda                  0.003400
# Location_Chennai             0.003223
# Location_Bangalore           0.002849
# ...

# %% [markdown]
# **Observation:**

# %% [markdown]
# - The most important feature is "Power," with an importance score of approximately 0.548.
# - The second most important feature is "Year" with an importance score of approximately 0.205.
# - The "kilometers_driven_log," "Engine," and "Mileage" features also have some importance, though not as high as "Power" and "Year."
# - Some features have very low importance scores, close to zero, indicating that they have little to no impact on the model's predictions. These features include "Brand_Bentley," "Fuel_Type_Electric," "Brand_Hindustan," and others.

# %% [markdown]
# ### **Hyperparameter Tuning: Random Forest**

# %%
# Import
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, mean_squared_error

# Choose the type of Regressor
rf_regressor_tuned = RandomForestRegressor(random_state = 1)

# Define the parameters for Grid to choose from 
print(rf_regressor.get_params())

param_grid = {
    'n_estimators': [100, 200, 300],  # Number of trees in the forest
    'max_depth': [None, 10, 20, 30],  # Maximum depth of the trees
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4],  # Minimum number of samples required to be at a leaf node
}
          
# Type of scoring used to compare parameter combinations
from sklearn.metrics import make_scorer
scorer = make_scorer(mean_squared_error, greater_is_better=False)
                 
# Run the grid search              
grid_obj = GridSearchCV(estimator=rf_regressor_tuned, param_grid=parameters, scoring=scorer)
grid_obj = grid_obj.fit(X, y)  # Replace X and y with your feature and target data

# Set the model to the best combination of parameters
rf_regressor_tuned= grid_obj.best_estimator_
                 
# Fit the best algorithm to the data
rf_regressor_tuned.fit(X, y)
# Out:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': 1, 'verbose': 0, 'warm_start': False}
# RandomForestRegressor(max_depth=15, min_samples_leaf=2, min_samples_split=10,
#                       random_state=1)

# %%
# Get score of the model
rf_regressor_tuned_perf = get_model_score(rf_regressor_tuned, flag=True)

rf_regressor_tuned_perf
# Out:
# R-squared on training set: 0.889
# R-square on test set: 0.901
# RMSE on training set: 0.266
# RMSE on test set : 0.250
# MAE on training set: 0.421
# MAE on test set: 0.414
#       R-Squared   RMSE    MAE
# train     0.889  0.266  0.177
# test      0.901  0.250  0.171

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Both rf_regressor and rf_regressor_tuned seem to perform well
# - The rf_regressor_tuned model exhibits better performance on the test data than on the training data, which is a positive sign of good generalization.
# - The rf_regressor model also performs well, though there is a slight drop in R² and an increase in RMSE and MAE from training to test data, which is typical but not a concern.

# %% [markdown]
# **Feature Importance**

# %%
# Plotting the feature importance
feature_importances = rf_regressor_tuned.feature_importances_
columns = X.columns;
importance_df_astro = pd.DataFrame(importances, index=columns, columns=['Importance']).sort_values(by='Importance', ascending=False);
plt.figure(figsize=(13,13));
sns.barplot(x=importance_df_astro.Importance,y= importance_df_astro.index)
plt.show()

print(importance_df_astro)
# Out:
#                            Importance
# Power                        0.543162
# Year                         0.204800
# kilometers_driven_log        0.060449
# Engine                       0.039882
# Mileage                      0.032374
# New_price                    0.013566
# Brand_Land                   0.007766
# Location_Kolkata             0.006427
# Seats                        0.005305
# Location_Hyderabad           0.005146
# Location_Coimbatore          0.005118
# Owner_Type_Second            0.005037
# Brand_Tata                   0.004421
# Location_Kochi               0.004058
# Location_Mumbai              0.004033
# Location_Pune                0.003866
# Brand_Mercedes-Benz          0.003769
# Location_Jaipur              0.003664
# Location_Delhi               0.003620
# Brand_BMW                    0.003435
# Transmission_Manual          0.003413
# Brand_Honda                  0.003400
# Location_Chennai             0.003223
# Location_Bangalore           0.002849
# ...

# %% [markdown]
# **Observation:**

# %% [markdown]
# - The most important feature is "Power," with an importance score of approximately 0.548.
# - The second most important feature is "Year" with an importance score of approximately 0.205.
# - Features like "kilometers_driven_log," "Engine," "Mileage," and "New_price" also have some importance, though not as high as "Power" and "Year."
# - Some features have very low importance scores, close to zero, indicating that they have little to no impact on the model's predictions. These features include "Brand_Bentley," "Fuel_Type_Electric," "Brand_Hindustan," and others.

# %% [markdown]
# **The order of importance in dt_regressor_tuned is the same as in rf_regressor_tuned**

# %% [markdown]
# ## **Conclusions and Recommendations**

# %% [markdown]
# In the context of regression, we can compare models based on various performance metrics, such as Mean Squared Error (MSE), Root Mean Squared Error (RMSE), Mean Absolute Error (MAE), R-squared.
#
# Comparing different machine learning models is an important step in the modeling process, as it allows us to understand the strengths and weaknesses of each model, and to choose the best one for a particular task.

# %% [markdown]
# **1. Comparison of various techniques and their relative performance based on chosen Metric (Measure of success):**
# - How do different techniques perform? Which one is performing relatively better? Is there scope to improve the performance further?

# %%
# Defining list of models you have trained
model_performance= [lr_perf, ridge_model_perf, dt_regressor_perf,rf_regressor_perf, dt_regressor_tuned_perf,rf_regressor_tuned_perf]
model=["lr", "ridge_model","dt_regressor","rf_regressor","dt_regressor_tuned","rf_regressor_tuned"]
for i, perf in enumerate(model_performance):
    perf['model']=model[i]

perf_df= pd.concat([lr_perf, ridge_model_perf, dt_regressor_perf,rf_regressor_perf, dt_regressor_tuned_perf,rf_regressor_tuned_perf], ignore_index=False)

perf_df
# Out:
#       R-Squared   RMSE    MAE               model
# train     0.770  0.382  0.267                  lr
# test      0.792  0.363  0.261                  lr
# train     0.770  0.382  0.268         ridge_model
# test      0.793  0.363  0.261         ridge_model
# train     1.000  0.008  0.000        dt_regressor
# test      0.561  0.528  0.333        dt_regressor
# train     0.964  0.150  0.097        rf_regressor
# test      0.762  0.388  0.260        rf_regressor
# train     0.715  0.425  0.307  dt_regressor_tuned
# test      0.743  0.404  0.297  dt_regressor_tuned
# train     0.889  0.266  0.177  rf_regressor_tuned
# test      0.901  0.250  0.171  rf_regressor_tuned

# %% [markdown]
# **To determine the best and final model to be adopted, we should consider several factors, including the evaluation metrics (R-squared, RMSE, MAE) on both the training and test data, as well as practical considerations. The choice of the final model will depend on the specific goals and requirements of the project.**

# %% [markdown]
# **Observation:**

# %% [markdown]
# - Based on the evaluation metrics and considering the trade-off between model complexity and performance, the "Tuned Random Forest Regressor (rf_regressor_tuned)" appears to be the best model. It has a high R-squared value on both the training and test data, indicating good predictive performance.
# - Additionally, it has the lowest RMSE and MAE on the test data, which suggests that it provides accurate predictions.
# - The most important feature (variable) that has the most significant impact on the model's predictions is Power, followed by Year and features like "kilometers_driven_log," "Engine," "Mileage," and "New_price" also have some importance, though not as high as "Power" and "Year."
# - The rest of the variables have little or no influence on the prediction of used cars
# - You may want to perform further testing and validation to ensure that the selected model generalizes well to unseen data. Techniques such as K_Nearest Neighbors (KNN) to compare the performance with the above techniques or k-fold cross-validation to assess the model's performance on different subsets of the data and detect overfitting more accurately.

# %% [markdown]
# **2. Refined insights:**
# - What are the most meaningful insights relevant to the problem?

# %% [markdown]
# In 2018-19, while new car sales were recorded at 3.6 million units, around 4 million second-hand cars were bought and sold. Predicting used cars prices become valuable in a market where prices vary significantly based on many factors such as those studied in this project.
# Some meaningful insights relevant to the problem and drawn from this project are listed below.
#
# Most used cars
# - are sold or purchased in Mumbai, followed by Hyderabad
# - use Diesel as fuel, followed by Petrol.
# - are no electric cars
# - are Manual
# - are first-owned
# - have 5 seats
# - are manufactured in 2014 and 2015, followed by 2016.
#
# Most expensive
# - used cars are sold or purchased in both Coimbatore and Bangalore
# - are Automatic cars
# - are first-owned
# - use Diesel as fuel
# - "Delhi" location has a negative impact on the Price
# - Being in the "Coimbatore" location has a positive impact on the Price.
# - Having the "Third" owner type negatively affects the Price
# - An increase in Power has a positive impact on the Price.
#
# Newer cars tend to command higher prices. Businesses should consider offering customers an option to search for cars based on specific years of manufacture. Additionally, understanding the depreciation rates of different car models over time can help in setting competitive prices.
#
# Cars with higher engine capacity often have higher price tags. Businesses should take this into account when setting prices for cars with varying power levels. Providing filters for power ranges can enhance the user experience
# In addition to engine capacity, other engine specifications, such as fuel efficiency, emissions, and type (e.g., diesel or petrol), can impact pricing. Buyers may have preferences based on these specifications, and businesses should highlight them in listings.
#
# The number of previous owners can influence price. Single-owner cars are often priced higher due to perceived reliability. Businesses should encourage sellers to provide accurate owner history and emphasize single-owner cars in listings.
#
# Automatic transmissions are more expensive but Manual are most frequently sold or purchased . Offering users the option to filter based on transmission preference can make the platform more user-friendly. Prominently displaying transmission type in listings can also help buyers quickly identify suitable options.
#
# There are no electric cars. Ultimately, the adoption of electric vehicles is a growing trend, and businesses that strategically position themselves in this market can benefit from changing consumer preferences and increasing environmental awareness.
#
# Diesel fuel cars are the most expensive and the most frequent. Highlighting fuel efficiency and long-term cost savings in listings can attract cost-conscious buyers. Offering eco-friendly options may also appeal to environmentally conscious consumers.
#
# Location: Geographical location plays a crucial role in used car prices. Urban areas or regions with higher demand may command higher prices. Businesses should consider offering location-specific pricing or search filters to account for these variations.
#
# Use features like Power, Year, kilometers_driven_log, Engine, Mileage, and New_price to get the most significant impact from the model'predictions chosen.

# %% [markdown]
# **3. Proposal for the final solution design:**
# - What model do you propose to be adopted? Why is this the best solution to adopt? What are expected benefits and costs (assume numbers) of this solution design?

# %% [markdown]
# - Compared to all the techniques chosen above,  the performance of Random Forest Tuned (rf_regressor_tuned) model has improved and shown to be the best model among all, even though some performed good as well.
# - Hence, we can choose the Random Forest Tuned model as the final model.
# - **Expected benefit:** The "Tuned Random Forest Regressor" model is likely to provide accurate predictions of the Price_log feature, which can be valuable for various applications, such as used cars or others pricing predictions or decision support.
# - **Expected cost:** Random Forest models can be computationally expensive, especially if the dataset is large. The training process may take longer and require more computational resources.

# %% [markdown]
# ## **Recommendations for Implementation**

# %% [markdown]
# Implementing a Random Forest tuned model for used car price prediction can lead to improved accuracy, better decision-making, reduced uncertainty, increased customer satisfaction, and a competitive advantage in the market. Businesses can strategically position themselves, reduce costs, and leverage data-driven insights for growth and success. The model is likely to provide accurate predictions of the Price_log feature, which can be valuable for various applications, such as used cars or others pricing predictions or decision support.
#
# Business Recommendations: Businesses in the used car market in India can benefit from implementing the following recommendations:
#
# - Offer users the ability to search for cars based on specific manufacturing years.
# - Offer users the ability to search for cars based on specific manufacturing years.
# - Highlight engine capacity and other power specifications in listings.
# - Display transmission type in listings and provide filters based on transmission preference.
# - Consider entering the growing electric vehicle market. Highlight fuel efficiency, especially for diesel vehicles.
# - Offer location-specific pricing or search filters to account for geographical variations.
# - Utilize data-driven pricing models that consider features like Power, Year, kilometers_driven_log, Engine, Mileage, and New_price for effective pricing.
#
# Recommendation for further analysis We may want to perform further testing and validation to ensure that the selected model generalizes well to unseen data. Techniques such as K_Nearest Neighbors (KNN) to compare the performance with the above techniques or k-fold cross-validation to assess the model's performance on different subsets of the data and detect overfitting more accurately.
